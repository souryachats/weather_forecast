# %%
import requests
myobj = {'date': '2011-01-01'}

x = requests.post('http://127.0.0.1:8080/report/date', json = myobj, auth=('dev', 'test_password'))

print(x.text)
if(x.status_code == 200):
    print("ok")
# Out:
# {
#   "2011-01-01T00:00": 0.9,
#   "2011-01-01T01:00": 0.8,
#   "2011-01-01T02:00": 0.6,
#   "2011-01-01T03:00": 0.5,
#   "2011-01-01T04:00": 0.9,
#   "2011-01-01T05:00": 1.5,
#   "2011-01-01T06:00": 2.0,
#   "2011-01-01T07:00": 2.1,
#   "2011-01-01T08:00": 2.4,
#   "2011-01-01T09:00": 2.8,
#   "2011-01-01T10:00": 2.9,
#   "2011-01-01T11:00": 3.0,
#   "2011-01-01T12:00": 3.1,
#   "2011-01-01T13:00": 2.9,
#   "2011-01-01T14:00": 2.6,
#   "2011-01-01T15:00": 2.3,
#   "2011-01-01T16:00": 1.8,
#   "2011-01-01T17:00": 1.5,
#   "2011-01-01T18:00": 0.8,
#   "2011-01-01T19:00": 0.5,
#   "2011-01-01T20:00": -0.0,
#   "2011-01-01T21:00": -0.2,
#   "2011-01-01T22:00": -0.2,
#   "2011-01-01T23:00": -0.2
# }
#
# ok

# %%
import requests
myobj = {'date': '2023-01-01'}

x = requests.post('http://127.0.0.1:8080/forecast/date', json = myobj, auth=('dev', 'test_password'))

print(x.text)
if(x.status_code == 200):
    print("ok")
# Out:
# {"lower temperature":{"0":13.658972678,"1":12.5073343763,"2":11.8062293701,"3":11.1708377831,"4":10.6817117756,"5":10.2624354257,"6":9.9080222047,"7":9.48881852,"8":9.1744541344,"9":8.8229031749,"10":8.4039550707,"11":8.0703705959,"12":7.8463021931,"13":7.663164338,"14":7.4843936948,"15":7.3096928752,"16":7.1387976462,"17":6.9714719546,"18":6.8075038728,"19":6.6467022669,"20":6.4888940334,"21":6.3339217928,"22":6.1816419492,"23":6.0319230476},"upper temperature":{"0":15.9056724044,"1":16.8292332017,"2":17.4865429694,"3":17.9390916978,"4":18.382935471,"5":18.7926675291,"6":19.1912027846,"7":19.466129401,"8":19.798618651,"9":20.0548219218,"10":20.2105740798,"11":20.4232557295,"12":20.6003889568,"13":20.7375816357,"14":20.8704813102,"15":20.9993852488,"16":21.1245575649,"17":21.2462341922,"18":21.3646269388,"19":21.4799268198,"20":21.5923068198,"21":21.7019241994,"22":21.8089224362,"23":21.9134328668},"Predictions":{"0":14.7823225412,"1":14.668283789,"2":14.6463861698,"3":14.5549647405,
# ...

# %%
import requests
myobj = {'date': '2023-01-01'}

x = requests.post('http://127.0.0.1:8080/forecast/date', json = myobj, auth=('dev', 'password'))

if(x.status_code == 401):
    print("ok")
# Out:
# ok
